# %%
import os, requests, time, json, glob
from io import StringIO
from datetime import date
from datetime import timedelta 
import matplotlib.pyplot as plt

import pandas as pd
import geopandas as gpd
#import h3pandas

from geoalchemy2 import Geometry, WKTElement
import psycopg2
from sqlalchemy import create_engine

from pandas import json_normalize
import urllib, urllib3, urllib.parse

# %%
df = pd.read_csv('datasets/fake_real_estate.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  real_estate_id           real_estate_owner  \
# 0           0               1              Hardin-Johnson
# 1           1               2  Taylor, Hernandez and Hill
# 2           2               3                Cole-Spencer
# 3           3               4     Brown, Harvey and Cohen
# 4           4               5                  Peters Inc
#
#                    street_address             business_name         state  \
# 0             520 Gonzalez Canyon   Kelley, Carter and Bass      New York
# 1           56147 Christian Trail  Hudson, Hansen and Garza      Kentucky
# 2       04608 Price Club Apt. 938                Morrow Inc       Alabama
# 3           915 Robinson Crossing             Mccoy-Jackson  Rhode Island
# 4  23558 Carlson Greens Suite 969              Thomas Group     Minnesota
#
#    zip_code  num_investors      cost building_type building_material  \
# 0     82411             42  99506.14    Industrial             Brick
# 1     75828             29  50316.71   Residential              Wood
# 2      1963             44  75621.33   Residential              Wood
# 3     84569             47  66873.80   Residential          Concrete
# 4     75556             94  75599.40    Industrial             Steel
#
#    insured_value           city   latitude   longitude
# 0       57255.24       Reedland -11.146982  114.809570
# 1       28110.78   South Robert -15.160265  133.957904
# 2       38882.34  New Davidstad  67.134105  129.557238
# 3       38505.74    Kelseyville  24.604504  -37.375721
# 4       92375.39     Arthurfurt  10.701648  -23.104486

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# %%
gdf.head(5)
# Out:
#    Unnamed: 0  real_estate_id           real_estate_owner  \
# 0           0               1              Hardin-Johnson
# 1           1               2  Taylor, Hernandez and Hill
# 2           2               3                Cole-Spencer
# 3           3               4     Brown, Harvey and Cohen
# 4           4               5                  Peters Inc
#
#                    street_address             business_name         state  \
# 0             520 Gonzalez Canyon   Kelley, Carter and Bass      New York
# 1           56147 Christian Trail  Hudson, Hansen and Garza      Kentucky
# 2       04608 Price Club Apt. 938                Morrow Inc       Alabama
# 3           915 Robinson Crossing             Mccoy-Jackson  Rhode Island
# 4  23558 Carlson Greens Suite 969              Thomas Group     Minnesota
#
#    zip_code  num_investors      cost building_type building_material  \
# 0     82411             42  99506.14    Industrial             Brick
# 1     75828             29  50316.71   Residential              Wood
# 2      1963             44  75621.33   Residential              Wood
# 3     84569             47  66873.80   Residential          Concrete
# 4     75556             94  75599.40    Industrial             Steel
#
#    insured_value           city   latitude   longitude  \
# 0       57255.24       Reedland -11.146982  114.809570
# 1       28110.78   South Robert -15.160265  133.957904
# 2       38882.34  New Davidstad  67.134105  129.557238
# 3       38505.74    Kelseyville  24.604504  -37.375721
# 4       92375.39     Arthurfurt  10.701648  -23.104486
#
#                       geometry
# 0  POINT (114.80957 -11.14698)
# 1  POINT (133.95790 -15.16027)
# 2   POINT (129.55724 67.13410)
# 3   POINT (-37.37572 24.60450)
# 4   POINT (-23.10449 10.70165)

# %%
gdf.to_file('datasets/fake_real_estate.gpkg', driver='GPKG', layer='name')
# Out:
# /Users/ /miniforge3/envs/awesome/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
