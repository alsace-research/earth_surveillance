# %%
import pandas as pd
import geopandas as gpd
import os, us, warnings, datetime
from sqlalchemy import create_engine  
from datetime import datetime
from pathlib import Path
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Prepare US state geo data

# %%
def generate_state_abbreviations():
    return {state.name: state.abbr for state in us.STATES_AND_TERRITORIES}

state_abbreviations = generate_state_abbreviations()
print(state_abbreviations)
# Out:
# {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY', 'American Samoa': 'AS', 'Guam': 'GU', 'Northern Mariana Islands': 'MP', 'Puerto Rico': 'PR', 'Virgin Islands': 'VI'}

# %%
# Load US states GeoDataFrame
us_states = gpd.read_file("https://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_040_00_5m.json")
us_states['area'] = us_states.geometry.area
us_states = us_states.sort_values(by='area', ascending=True)
us_states['st'] = us_states['NAME'].map(state_abbreviations)
us_states.head(5)
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA
# 8   0400000US11    11  District of Columbia           61.048  \
# 39  0400000US44    44          Rhode Island         1033.814
# 7   0400000US10    10              Delaware         1948.543
# 51  0400000US72    72           Puerto Rico         3423.775
# 6   0400000US09    09           Connecticut         4842.355
#
#                                              geometry      area   st
# 8   POLYGON ((-77.03860 38.79151, -77.03890 38.800...  0.018380  NaN
# 39  MULTIPOLYGON (((-71.38359 41.46478, -71.38928 ...  0.309236   RI
# 7   MULTIPOLYGON (((-75.56493 39.58325, -75.57627 ...  0.545358   DE
# 51  MULTIPOLYGON (((-65.32770 18.29584, -65.33745 ...  0.765080   PR
# 6   POLYGON ((-71.79924 42.00807, -71.79792 41.935...  1.395161   CT

# %% [markdown]
# ### For each US state, spatial join and aggregate Tornado data into H3 hexagons

# %%
def calculate_years_diff(dates_list):
    if len(dates_list) > 1:
        years_diff = [(dates_list[i] - dates_list[i - 1]).days / 365.25 for i in range(1, len(dates_list))]
        return [round(year_diff, 3) for year_diff in years_diff]
    else:
        return []

def calculate_days_diff(dates):
    if len(dates) > 1:
        sorted_dates = sorted(dates)
        return [(sorted_dates[i + 1] - sorted_dates[i]).days for i in range(len(sorted_dates) - 1)]
    else:
        return []

from datetime import datetime

def convert_to_date(dates_list):
    return [datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_list]

# Define a function that calculates the years between the event date and the present date
def years_since_event(dates):
    if len(dates) == 1:
        # if there is only one event, calculate the years since that event
        return (datetime.now().date() - dates[0]).days / 365.25
    else:
        # if there are multiple events, return None (or whatever you want to return in this case)
        return None

# %%
def load_geodata(state_name, directory):
    print(f"Read in geoDataframe for : {state_name}")
    st_boundary = us_states[us_states['st'] == state_name]
    st_boundary = st_boundary.to_crs(4326)
    print(f"Loading H3 id's and polygons for: {state_name}")
    try:
        full_name = st_boundary['NAME'].iloc[0]
    except IndexError:
        raise Exception("IndexError: The DataFrame st_boundary is likely empty or the index is out of bounds.")

    print("We've created the two state objects: full_name and abbreviated name")
    hexagons = gpd.read_file(f"{directory}/h3_by_state/h3_{full_name}.gpkg")
    hexagons['state'] = state_name
    lookup = hexagons['state'][0]
    st_boundary = st_boundary.dropna()

    return hexagons, lookup, st_boundary

def load_event_data(directory, lookup, st_boundary):
    event = gpd.read_file(f"{directory}/input/tornado_tracks.shp")
    event = event.to_crs(4326)
    event_df = event[event['st'] == lookup]
    print("Created event geoDataframe")
    event_df = gpd.clip(event_df, st_boundary)
    return event_df

# %%
def process_event_history(s):
    # Regular expression pattern to match the dates
    pattern = r'datetime\.date\((\d{4}), (\d{1,2}), (\d{1,2})\)'

    # Extract all matching date components
    matches = re.findall(pattern, s)

    # Convert to formatted date strings
    formatted_dates = [datetime(int(year), int(month), int(day)).strftime('%m/%d/%Y') for year, month, day in matches]

    return formatted_dates

# %%
print(us_states['st'].unique())
# Out:
# [nan 'RI' 'DE' 'PR' 'CT' 'HI' 'NJ' 'MA' 'NH' 'VT' 'MD' 'WV' 'SC' 'ME' 'IN'
#  'KY' 'VA' 'TN' 'OH' 'LA' 'MS' 'PA' 'NC' 'AL' 'AR' 'FL' 'NY' 'GA' 'IL'
#  'IA' 'WI' 'MI' 'OK' 'MO' 'WA' 'NE' 'ND' 'KS' 'SD' 'UT' 'ID' 'MN' 'WY'
#  'CO' 'OR' 'AZ' 'NV' 'NM' 'CA' 'MT' 'TX' 'AK']

# %%
# Set directory path
directory = Path("/Users//Documents/engineering//tornado/data")
output_directory = "h3_hexagons_geopackage"

# Loop through each state name
for state_name in us_states['st'].dropna().unique():
    try:
        print("________________________________________________________________")
        hexagons, lookup, st_boundary = load_geodata(state_name, directory)
        event_df = load_event_data(directory, lookup, st_boundary)

        # Rest of the processing steps would go here...
        # Clip the data using GeoPandas clip
        event_df = gpd.clip(event_df, st_boundary)
        event_df['buffer_geom'] = event_df.buffer(0.008)
        event_df = event_df.drop('geometry', axis=1)
        event_df = event_df.rename(columns={'buffer_geom': 'geometry'})
        print(f"Loading Tornado event layer by the state of: {lookup}")

        # Convert column A from float to string and remove ".0"
        event_df['yr'] = event_df['yr'].astype(int).astype(str).str.replace('\.0', '')
        event_df['mo'] = event_df['mo'].astype(int).astype(str).str.replace('\.0', '')
        event_df['dy'] = event_df['dy'].astype(int).astype(str).str.replace('\.0', '')

                # select only float columns
        float_cols = event_df.select_dtypes(include=['float'])

        # round float columns to 2 decimal places
        event_df[float_cols.columns] = float_cols.round(2)

        #event_df['date'] = pd.to_datetime(event_df['date'], errors='coerce').dt.date
        event_df = event_df[['geometry', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'mag', 'inj',
        'fat', 'loss', 'closs', 'len', 'wid']]
        print("Start Join of geoDataframe")

        # Use geopandas to spatial join *intersect* the two tables
        join_df = gpd.sjoin(hexagons, event_df, how='inner', predicate='intersects')
        print(f"Resulted join has a record count of: {len(join_df.index)}")

        # Sort and group the data to produce aggregate layer
        join_df = join_df.sort_values(by=['h3_hexagon', 'date'], ascending=True)
        group_df = join_df.groupby('h3_hexagon').agg({
            'yr': list, 
            'mo': list, 
            'date': list, 
            'mag': list, 
            'loss': list, 
            'closs': list, 
            'inj': list, 
            'fat': list, 
            'len': list, 
            'wid': list
            })
        print("Aggregating event geoDataframe")

        # Convert the strings in the 'date' column to datetime.date objects
        group_df['date'] = group_df['date'].apply(convert_to_date)

        # Calculate days difference between dates in the 'date' column
        group_df['days_diff'] = group_df['date'].apply(calculate_days_diff)
        group_df['years_diff'] = group_df['date'].apply(calculate_years_diff)

        # Calculate total number of tornado events and sum of years difference
        group_df['num_events'] = group_df['date'].apply(len)
        group_df['sum_years_diff'] = group_df['years_diff'].apply(sum)
        group_df['sum_property_loss'] = group_df['loss'].apply(sum)

        # Calculate the average loss per year
        group_df['total_loss'] = group_df['loss'].apply(sum)
        group_df['total_years'] = group_df['date'].apply(len)
        group_df['avg_loss_per_year'] = group_df['total_loss'] / group_df['total_years']

        ######## Addition
        # Apply the function to the 'date' column
        group_df['years_since_event'] = group_df['date'].apply(years_since_event)

        # replace zero or null values with np.nan
        group_df['sum_years_diff'] = group_df['sum_years_diff'].replace({0: np.nan, None: np.nan})

        # Now use 'years_since_event' where 'sum_years_diff' is null
        group_df['sum_years_diff'] = group_df['sum_years_diff'].where(group_df['sum_years_diff'].notnull(), group_df['years_since_event'])

        # Now calculate average frequency as before
        group_df['avg_frequency'] = group_df['num_events'] / group_df['sum_years_diff']
        ######## End Addition

        # Calculate average frequency
        group_df['avg_property_loss'] = group_df['sum_property_loss'] / group_df['num_events']
        # Calculate average frequency of mag_stats#
        group_df['avg_mag_freq'] = group_df['num_events'] / group_df['sum_years_diff']

        print("Dissolving event geoDataframe")
        # Run a Group By and Sum operation to produce aggregate layer
        dissolve_df = join_df.dissolve(
                by="h3_hexagon",
                aggfunc={'state': 'count',
                        'mag':'mean', 'inj': 'sum', 
                        'fat': 'sum', 'loss': 'sum', 
                        'closs': 'sum', 'len': 'mean', 'wid': 'mean'})

        dissolve_df = dissolve_df.rename(columns={'h3_hexagon':'h3_id', 'name':'tornado_count'})

        # Merge the two dataframes to produce final aggregate layer
        final = dissolve_df.join(group_df, lsuffix='_h3_history', rsuffix='_stats')
        final = final.rename(columns={'state': 'tornado_count'})

        df_melt = final.assign(names=final.date.str.split(","))
                
        final = df_melt.date.apply(pd.Series) \
            .merge(df_melt, right_index=True, left_index=True)

        final['date'] = final['date'].apply(convert_to_string)


        ##############################

        print("Successfully dissolved...")
        final.to_csv(f"{directory}/h3_hexagons_tornado/{lookup}_final_geom.csv")
        print("Wrote to csv...")
    except FileNotFoundError as e:
        print(f"Error processing {state_name}: {e}")
    except ValueError as e:
        print(f"Error processing {state_name}: {e}")
# Out:
# ________________________________________________________________
# Read in geoDataframe for : RI
# Loading H3 id's and polygons for: RI
# We've created the two state objects: full_name and abbreviated name
# Created event geoDataframe
# Loading Tornado event layer by the state of: RI
# Start Join of geoDataframe
# Resulted join has a record count of: 944
# Aggregating event geoDataframe
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users//Documents/engineering//tornado/notebooks/03. dissolve_hexagons.ipynb Cell 10 in <cell line: 6>()
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=53'>54</a> print("Aggregating event geoDataframe")
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=55'>56</a> # Convert the strings in the 'date' column to datetime.date objects
# ---> <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=56'>57</a> group_df['date'] = group_df['date'].apply(convert_to_date)
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=58'>59</a> # Calculate days difference between dates in the 'date' column
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=59'>60</a> group_df['days_diff'] = group_df['date'].apply(calculate_days_diff)
#
# File ~/mambaforge/envs/myenv/lib/python3.8/site-packages/pandas/core/series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/mambaforge/envs/myenv/lib/python3.8/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/mambaforge/envs/myenv/lib/python3.8/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/mambaforge/envs/myenv/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# /Users//Documents/engineering//tornado/notebooks/03. dissolve_hexagons.ipynb Cell 10 in convert_to_date(dates_list)
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> def convert_to_date(dates_list):
# ---> <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a>     return [datetime.datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_list]
#
# /Users//Documents/engineering//tornado/notebooks/03. dissolve_hexagons.ipynb Cell 10 in <listcomp>(.0)
#      <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> def convert_to_date(dates_list):
# ---> <a href='vscode-notebook-cell:/Users//Documents/engineering//tornado/notebooks/03.%20dissolve_hexagons.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a>     return [datetime.datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_list]
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %% [markdown]
# ## Step-by-Step Model: DO NOT DELETE

# %%
from pathlib import Path
import glob

# Set directory path
directory = Path("/alsaceh/tornado/data")
output_directory = "h3_hexagons_geopackage"


# Specify the state you want to process
state_name = 'AR'

hexagons, lookup, st_boundary = load_geodata(state_name, directory)
event_df = load_event_data(directory, lookup, st_boundary)
# Out:
# Read in geoDataframe for : AR
# Loading H3 id's and polygons for: AR
# We've created the two state objects: full_name and abbreviated name
# Created event geoDataframe

# %%
# Rest of the processing steps would go here...
# Clip the data using GeoPandas clip
event_df = gpd.clip(event_df, st_boundary)
event_df['buffer_geom'] = event_df.buffer(0.008)
event_df = event_df.drop('geometry', axis=1)
event_df = event_df.rename(columns={'buffer_geom': 'geometry'})
print(f"Loading Tornado event layer by the state of: {lookup}")
# Out:
# Loading Tornado event layer by the state of: AR
# /var/folders/n4/p2lmf2l94x3gfqhs72xx2zwr0000gn/T/ipykernel_90911/806601991.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   event_df['buffer_geom'] = event_df.buffer(0.008)

# %%
event_df.head(3)
# Out:
#        OBJECTID        om      yr   mo    dy        date      time   tz  st
# 9635     9636.0     127.0  1967.0  4.0  13.0  1967-04-13  18:00:00  3.0  AR  \
# 62941   62942.0  616091.0  2018.0  4.0  14.0  2018-04-14  01:42:00  3.0  AR
# 52575   52576.0     200.0  2009.0  4.0   9.0  2009-04-09  22:27:00  3.0  AR
#
#        stf  ...     slon     elat     elon    len    wid   fc    Shape__Len
# 9635   5.0  ... -91.9000  33.0201 -91.8999   0.10   10.0  0.0     17.325684  \
# 62941  5.0  ... -92.0066  33.0325 -91.9634   2.72  600.0  0.0   5230.834624
# 52575  5.0  ... -92.0012  33.0365 -91.7681  13.60  600.0  0.0  26129.197920
#
#        Month_Calc     Date_Calc
# 9635          3.0 -8.586360e+10  \
# 62941         3.0  1.523678e+12
# 52575         3.0  1.239250e+12
#
#                                                 geometry
# 9635   POLYGON ((-91.90556 33.02576, -91.90498 33.026...
# 62941  POLYGON ((-91.96610 33.04003, -91.96535 33.040...
# 52575  POLYGON ((-91.76889 33.04446, -91.76810 33.044...
#
# [3 rows x 27 columns]

# %%
# Convert column A from float to string and remove ".0"
event_df['yr'] = event_df['yr'].astype(int).astype(str).str.replace('\.0', '')
event_df['mo'] = event_df['mo'].astype(int).astype(str).str.replace('\.0', '')
event_df['dy'] = event_df['dy'].astype(int).astype(str).str.replace('\.0', '')

# %%
event_df.head(3)
# Out:
#        OBJECTID        om    yr mo  dy        date      time   tz  st  stf
# 9635     9636.0     127.0  1967  4  13  1967-04-13  18:00:00  3.0  AR  5.0  \
# 62941   62942.0  616091.0  2018  4  14  2018-04-14  01:42:00  3.0  AR  5.0
# 52575   52576.0     200.0  2009  4   9  2009-04-09  22:27:00  3.0  AR  5.0
#
#        ...     slon     elat     elon    len    wid   fc    Shape__Len
# 9635   ... -91.9000  33.0201 -91.8999   0.10   10.0  0.0     17.325684  \
# 62941  ... -92.0066  33.0325 -91.9634   2.72  600.0  0.0   5230.834624
# 52575  ... -92.0012  33.0365 -91.7681  13.60  600.0  0.0  26129.197920
#
#        Month_Calc     Date_Calc
# 9635          3.0 -8.586360e+10  \
# 62941         3.0  1.523678e+12
# 52575         3.0  1.239250e+12
#
#                                                 geometry
# 9635   POLYGON ((-91.90556 33.02576, -91.90498 33.026...
# 62941  POLYGON ((-91.96610 33.04003, -91.96535 33.040...
# 52575  POLYGON ((-91.76889 33.04446, -91.76810 33.044...
#
# [3 rows x 27 columns]

# %%
# select only float columns
float_cols = event_df.select_dtypes(include=['float'])

# round float columns to 2 decimal places
event_df[float_cols.columns] = float_cols.round(2)

#event_df['date'] = pd.to_datetime(event_df['date'], errors='coerce').dt.date
event_df = event_df[['geometry', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'mag', 'inj',
'fat', 'loss', 'closs', 'len', 'wid']]
print("Start Join of geoDataframe")
# Out:
# Start Join of geoDataframe

# %%
# Use geopandas to spatial join *intersect* the two tables
join_df = gpd.sjoin(hexagons, event_df, how='inner', predicate='intersects')
print(f"Resulted join has a record count of: {len(join_df.index)}")

# Sort and group the data to produce aggregate layer
join_df = join_df.sort_values(by=['h3_hexagon', 'date'], ascending=True)

join_df.head(5)
# Out:
# Resulted join has a record count of: 368711
#               h3_hexagon                                           geometry
# 541011   89264ad92d3ffff  POLYGON ((-89.74671 35.92758, -89.74525 35.928...  \
# 1236875  89264ad92dbffff  POLYGON ((-89.75034 35.92670, -89.74888 35.928...
# 82334    89264ad9403ffff  POLYGON ((-89.71177 35.94471, -89.71031 35.946...
# 800306   89264ad940bffff  POLYGON ((-89.71541 35.94384, -89.71395 35.945...
# 66661    89264ad940fffff  POLYGON ((-89.71252 35.94161, -89.71106 35.942...
#
#         state  index_right    yr mo dy        date      time   tz  st  mag
# 541011     AR        36907  1997  3  1  1997-03-01  18:20:00  3.0  AR  4.0  \
# 1236875    AR        36907  1997  3  1  1997-03-01  18:20:00  3.0  AR  4.0
# 82334      AR        36907  1997  3  1  1997-03-01  18:20:00  3.0  AR  4.0
# 800306     AR        36907  1997  3  1  1997-03-01  18:20:00  3.0  AR  4.0
# 66661      AR        36907  1997  3  1  1997-03-01  18:20:00  3.0  AR  4.0
#
#          inj  fat  loss  closs   len    wid
# 541011   0.0  0.0  0.03    0.0  20.0  200.0
# 1236875  0.0  0.0  0.03    0.0  20.0  200.0
# 82334    0.0  0.0  0.03    0.0  20.0  200.0
# 800306   0.0  0.0  0.03    0.0  20.0  200.0
# 66661    0.0  0.0  0.03    0.0  20.0  200.0

# %%
group_df = join_df.groupby('h3_hexagon').agg({
    'yr': list, 
    'mo': list, 
    'date': list, 
    'mag': list, 
    'loss': list, 
    'closs': list, 
    'inj': list, 
    'fat': list, 
    'len': list, 
    'wid': list
    })
print("Aggregating event geoDataframe")

group_df.head(5)
# Out:
# Aggregating event geoDataframe
#                      yr   mo          date    mag    loss  closs    inj
# h3_hexagon
# 89264ad92d3ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]  \
# 89264ad92dbffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad9403ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940bffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940fffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
#
#                    fat     len      wid
# h3_hexagon
# 89264ad92d3ffff  [0.0]  [20.0]  [200.0]
# 89264ad92dbffff  [0.0]  [20.0]  [200.0]
# 89264ad9403ffff  [0.0]  [20.0]  [200.0]
# 89264ad940bffff  [0.0]  [20.0]  [200.0]
# 89264ad940fffff  [0.0]  [20.0]  [200.0]

# %%
import datetime

# Convert the strings in the 'date' column to datetime.date objects
group_df['date'] = group_df['date'].apply(convert_to_date)

# Calculate days difference between dates in the 'date' column
group_df['days_diff']_df['date'].apply(calculate_days_diff)

group_df['years_diff'] = group_df['date'].apply(calculate_years_diff)

# %%
group_df.head(5)
# Out:
#                      yr   mo          date    mag    loss  closs    inj
# h3_hexagon
# 89264ad92d3ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]  \
# 89264ad92dbffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad9403ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940bffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940fffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
#
#                    fat     len      wid days_diff years_diff
# h3_hexagon
# 89264ad92d3ffff  [0.0]  [20.0]  [200.0]        []         []
# 89264ad92dbffff  [0.0]  [20.0]  [200.0]        []         []
# 89264ad9403ffff  [0.0]  [20.0]  [200.0]        []         []
# 89264ad940bffff  [0.0]  [20.0]  [200.0]        []         []
# 89264ad940fffff  [0.0]  [20.0]  [200.0]        []         []

# %%
# Calculate total number of tornado events and sum of years difference
group_df['num_events'] = group_df['date'].apply(len)
group_df['sum_years_diff'] = group_df['years_diff'].apply(sum)
group_df['sum_property_loss'] = group_df['loss'].apply(sum)

group_df.head(5)

# %%
# Calculate the average loss per year
group_df['total_loss'] = group_df['loss'].apply(sum)
group_df['total_years'] = group_df['date'].apply(len)
group_df['avg_loss_per_year'] = group_df['total_loss'] / group_df['total_years']

group_df.head(5)
# Out:
#                      yr   mo          date    mag    loss  closs    inj
# h3_hexagon
# 89264ad92d3ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]  \
# 89264ad92dbffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad9403ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940bffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940fffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
#
#                    fat     len      wid days_diff years_diff  num_events
# h3_hexagon
# 89264ad92d3ffff  [0.0]  [20.0]  [200.0]        []         []           1  \
# 89264ad92dbffff  [0.0]  [20.0]  [200.0]        []         []           1
# 89264ad9403ffff  [0.0]  [20.0]  [200.0]        []         []           1
# 89264ad940bffff  [0.0]  [20.0]  [200.0]        []         []           1
# 89264ad940fffff  [0.0]  [20.0]  [200.0]        []         []           1
#
#                  sum_years_diff  sum_property_loss  total_loss  total_years
# h3_hexagon
# 89264ad92d3ffff             0.0               0.03        0.03            1  \
# 89264ad92dbffff             0.0               0.03        0.03            1
# 89264ad9403ffff             0.0               0.03        0.03            1
# 89264ad940bffff             0.0               0.03        0.03            1
# 89264ad940fffff             0.0               0.03        0.03            1
#
#                  avg_loss_per_year
# h3_hexagon
# 89264ad92d3ffff               0.03
# 89264ad92dbffff               0.03
# 89264ad9403ffff               0.03
# 89264ad940bffff               0.03
# 89264ad940fffff               0.03

# %%
from datetime import datetime


# replace zero or null values with np.nan
group_df['sum_years_diff'] = group_df['sum_years_diff'].replace({0: np.nan, None: np.nan})

# Apply the function to the 'date' column
group_df['years_since_event'] = group_df['date'].apply(years_since_event)

# Now use 'years_since_event' where 'sum_years_diff' is null
group_df['sum_years_diff'] = group_df['sum_years_diff'].where(group_df['sum_years_diff'].notnull(), group_df['years_since_event'])

# Now calculate average frequency as before
group_df['avg_frequency'] = group_df['num_events'] / group_df['sum_years_diff']

# %%
group_df.head(5)
# Out:
#                      yr   mo          date    mag    loss  closs    inj
# h3_hexagon
# 89264ad92d3ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]  \
# 89264ad92dbffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad9403ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940bffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940fffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
#
#                    fat     len      wid  ... num_events sum_years_diff
# h3_hexagon                               ...
# 89264ad92d3ffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824  \
# 89264ad92dbffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad9403ffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad940bffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad940fffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
#
#                  sum_property_loss  total_loss  total_years
# h3_hexagon
# 89264ad92d3ffff               0.03        0.03            1  \
# 89264ad92dbffff               0.03        0.03            1
# 89264ad9403ffff               0.03        0.03            1
# 89264ad940bffff               0.03        0.03            1
# 89264ad940fffff               0.03        0.03            1
#
#                  avg_loss_per_year  avg_frequency  avg_property_loss
# h3_hexagon
# 89264ad92d3ffff               0.03       0.038114               0.03  \
# 89264ad92dbffff               0.03       0.038114               0.03
# 89264ad9403ffff               0.03       0.038114               0.03
# 89264ad940bffff               0.03       0.038114               0.03
# 89264ad940fffff               0.03       0.038114               0.03
#
#                  avg_mag_freq  years_since_event
# h3_hexagon
# 89264ad92d3ffff           inf          26.236824
# 89264ad92dbffff           inf          26.236824
# 89264ad9403ffff           inf          26.236824
# 89264ad940bffff           inf          26.236824
# 89264ad940fffff           inf          26.236824
#
# [5 rows x 22 columns]

# %%
group_df['avg_property_loss'] = group_df['sum_property_loss'] / group_df['num_events']
# Calculate average frequency of mag_stats
group_df['avg_mag_freq'] = group_df['num_events'] / group_df['sum_years_diff']

group_df.head(5)
# Out:
#                      yr   mo          date    mag    loss  closs    inj
# h3_hexagon
# 89264ad92d3ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]  \
# 89264ad92dbffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad9403ffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940bffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
# 89264ad940fffff  [1997]  [3]  [1997-03-01]  [4.0]  [0.03]  [0.0]  [0.0]
#
#                    fat     len      wid  ... num_events sum_years_diff
# h3_hexagon                               ...
# 89264ad92d3ffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824  \
# 89264ad92dbffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad9403ffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad940bffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
# 89264ad940fffff  [0.0]  [20.0]  [200.0]  ...          1      26.236824
#
#                  sum_property_loss  total_loss  total_years
# h3_hexagon
# 89264ad92d3ffff               0.03        0.03            1  \
# 89264ad92dbffff               0.03        0.03            1
# 89264ad9403ffff               0.03        0.03            1
# 89264ad940bffff               0.03        0.03            1
# 89264ad940fffff               0.03        0.03            1
#
#                  avg_loss_per_year  avg_frequency  avg_property_loss
# h3_hexagon
# 89264ad92d3ffff               0.03       0.038114               0.03  \
# 89264ad92dbffff               0.03       0.038114               0.03
# 89264ad9403ffff               0.03       0.038114               0.03
# 89264ad940bffff               0.03       0.038114               0.03
# 89264ad940fffff               0.03       0.038114               0.03
#
#                  avg_mag_freq  years_since_event
# h3_hexagon
# 89264ad92d3ffff      0.038114          26.236824
# 89264ad92dbffff      0.038114          26.236824
# 89264ad9403ffff      0.038114          26.236824
# 89264ad940bffff      0.038114          26.236824
# 89264ad940fffff      0.038114          26.236824
#
# [5 rows x 22 columns]

# %%
print("Dissolving event geoDataframe")
# Run a Group By and Sum operation to produce aggregate layer
dissolve_df = join_df.dissolve(
        by="h3_hexagon",
        aggfunc={'state': 'count',
                'mag':'mean', 'inj': 'sum', 
                'fat': 'sum', 'loss': 'sum', 
                'closs': 'sum', 'len': 'mean', 'wid': 'mean'})


dissolve_df = dissolve_df.rename(columns={'h3_hexagon':'h3_id', 'name':'tornado_count'})

dissolve_df.head(3)
# Out:
# Dissolving event geoDataframe
#                                                           geometry  state
# h3_hexagon
# 89264ad92d3ffff  POLYGON ((-89.74671 35.92758, -89.74525 35.928...      1  \
# 89264ad92dbffff  POLYGON ((-89.75034 35.92670, -89.74888 35.928...      1
# 89264ad9403ffff  POLYGON ((-89.71177 35.94471, -89.71031 35.946...      1
#
#                  mag  inj  fat  loss  closs   len    wid
# h3_hexagon
# 89264ad92d3ffff  4.0  0.0  0.0  0.03    0.0  20.0  200.0
# 89264ad92dbffff  4.0  0.0  0.0  0.03    0.0  20.0  200.0
# 89264ad9403ffff  4.0  0.0  0.0  0.03    0.0  20.0  200.0

# %%
# Merge the two dataframes to produce final aggregate layer
final = dissolve_df.join(group_df, lsuffix='_h3_history', rsuffix='_stats')
final = final.rename(columns={'state': 'tornado_count'})

final.head(5)
# Out:
#                                                           geometry
# h3_hexagon
# 89264ad92d3ffff  POLYGON ((-89.74671 35.92758, -89.74525 35.928...  \
# 89264ad92dbffff  POLYGON ((-89.75034 35.92670, -89.74888 35.928...
# 89264ad9403ffff  POLYGON ((-89.71177 35.94471, -89.71031 35.946...
# 89264ad940bffff  POLYGON ((-89.71541 35.94384, -89.71395 35.945...
# 89264ad940fffff  POLYGON ((-89.71252 35.94161, -89.71106 35.942...
#
#                  tornado_count  mag_h3_history  inj_h3_history
# h3_hexagon
# 89264ad92d3ffff              1             4.0             0.0  \
# 89264ad92dbffff              1             4.0             0.0
# 89264ad9403ffff              1             4.0             0.0
# 89264ad940bffff              1             4.0             0.0
# 89264ad940fffff              1             4.0             0.0
#
#                  fat_h3_history  loss_h3_history  closs_h3_history
# h3_hexagon
# 89264ad92d3ffff             0.0             0.03               0.0  \
# 89264ad92dbffff             0.0             0.03               0.0
# 89264ad9403ffff             0.0             0.03               0.0
# 89264ad940bffff             0.0             0.03               0.0
# 89264ad940fffff             0.0             0.03               0.0
#
#                  len_h3_history  wid_h3_history      yr  ... num_events
# h3_hexagon                                               ...
# 89264ad92d3ffff            20.0           200.0  [1997]  ...          1  \
# 89264ad92dbffff            20.0           200.0  [1997]  ...          1
# 89264ad9403ffff            20.0           200.0  [1997]  ...          1
# 89264ad940bffff            20.0           200.0  [1997]  ...          1
# 89264ad940fffff            20.0           200.0  [1997]  ...          1
#
#                 sum_years_diff sum_property_loss total_loss total_years
# h3_hexagon
# 89264ad92d3ffff      26.236824              0.03       0.03           1  \
# 89264ad92dbffff      26.236824              0.03       0.03           1
# 89264ad9403ffff      26.236824              0.03       0.03           1
# 89264ad940bffff      26.236824              0.03       0.03           1
# 89264ad940fffff      26.236824              0.03       0.03           1
#
#                 avg_loss_per_year avg_frequency avg_property_loss
# h3_hexagon
# 89264ad92d3ffff              0.03      0.038114              0.03  \
# 89264ad92dbffff              0.03      0.038114              0.03
# 89264ad9403ffff              0.03      0.038114              0.03
# 89264ad940bffff              0.03      0.038114              0.03
# 89264ad940fffff              0.03      0.038114              0.03
#
#                 avg_mag_freq years_since_event
# h3_hexagon
# 89264ad92d3ffff     0.038114         26.236824
# 89264ad92dbffff     0.038114         26.236824
# 89264ad9403ffff     0.038114         26.236824
# 89264ad940bffff     0.038114         26.236824
# 89264ad940fffff     0.038114         26.236824
#
# [5 rows x 31 columns]

# %%
df_melt = final.assign(names=final.date.str.split(","))

df_melt.head(5)
# Out:
#                                                           geometry
# h3_hexagon
# 89264ad92d3ffff  POLYGON ((-89.74671 35.92758, -89.74525 35.928...  \
# 89264ad92dbffff  POLYGON ((-89.75034 35.92670, -89.74888 35.928...
# 89264ad9403ffff  POLYGON ((-89.71177 35.94471, -89.71031 35.946...
# 89264ad940bffff  POLYGON ((-89.71541 35.94384, -89.71395 35.945...
# 89264ad940fffff  POLYGON ((-89.71252 35.94161, -89.71106 35.942...
#
#                  tornado_count  mag_h3_history  inj_h3_history
# h3_hexagon
# 89264ad92d3ffff              1             4.0             0.0  \
# 89264ad92dbffff              1             4.0             0.0
# 89264ad9403ffff              1             4.0             0.0
# 89264ad940bffff              1             4.0             0.0
# 89264ad940fffff              1             4.0             0.0
#
#                  fat_h3_history  loss_h3_history  closs_h3_history
# h3_hexagon
# 89264ad92d3ffff             0.0             0.03               0.0  \
# 89264ad92dbffff             0.0             0.03               0.0
# 89264ad9403ffff             0.0             0.03               0.0
# 89264ad940bffff             0.0             0.03               0.0
# 89264ad940fffff             0.0             0.03               0.0
#
#                  len_h3_history  wid_h3_history      yr  ... sum_years_diff
# h3_hexagon                                               ...
# 89264ad92d3ffff            20.0           200.0  [1997]  ...      26.236824  \
# 89264ad92dbffff            20.0           200.0  [1997]  ...      26.236824
# 89264ad9403ffff            20.0           200.0  [1997]  ...      26.236824
# 89264ad940bffff            20.0           200.0  [1997]  ...      26.236824
# 89264ad940fffff            20.0           200.0  [1997]  ...      26.236824
#
#                 sum_property_loss total_loss total_years avg_loss_per_year
# h3_hexagon
# 89264ad92d3ffff              0.03       0.03           1              0.03  \
# 89264ad92dbffff              0.03       0.03           1              0.03
# 89264ad9403ffff              0.03       0.03           1              0.03
# 89264ad940bffff              0.03       0.03           1              0.03
# 89264ad940fffff              0.03       0.03           1              0.03
#
#                 avg_frequency avg_property_loss avg_mag_freq
# h3_hexagon
# 89264ad92d3ffff      0.038114              0.03     0.038114  \
# 89264ad92dbffff      0.038114              0.03     0.038114
# 89264ad9403ffff      0.038114              0.03     0.038114
# 89264ad940bffff      0.038114              0.03     0.038114
# 89264ad940fffff      0.038114              0.03     0.038114
#
#                 years_since_event names
# h3_hexagon
# 89264ad92d3ffff         26.236824   NaN
# 89264ad92dbffff         26.236824   NaN
# 89264ad9403ffff         26.236824   NaN
# 89264ad940bffff         26.236824   NaN
# 89264ad940fffff         26.236824   NaN
#
# [5 rows x 32 columns]

# %%
final = df_melt.date.apply(pd.Series) \
    .merge(df_melt, right_index=True, left_index=True)

final.head(5)
# Out:
#                           0    1    2    3    4    5    6
# h3_hexagon
# 89264ad92d3ffff  1997-03-01  NaN  NaN  NaN  NaN  NaN  NaN  \
# 89264ad92dbffff  1997-03-01  NaN  NaN  NaN  NaN  NaN  NaN
# 89264ad9403ffff  1997-03-01  NaN  NaN  NaN  NaN  NaN  NaN
# 89264ad940bffff  1997-03-01  NaN  NaN  NaN  NaN  NaN  NaN
# 89264ad940fffff  1997-03-01  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                           geometry
# h3_hexagon
# 89264ad92d3ffff  POLYGON ((-89.74671 35.92758, -89.74525 35.928...  \
# 89264ad92dbffff  POLYGON ((-89.75034 35.92670, -89.74888 35.928...
# 89264ad9403ffff  POLYGON ((-89.71177 35.94471, -89.71031 35.946...
# 89264ad940bffff  POLYGON ((-89.71541 35.94384, -89.71395 35.945...
# 89264ad940fffff  POLYGON ((-89.71252 35.94161, -89.71106 35.942...
#
#                  tornado_count  mag_h3_history  ...  num_events
# h3_hexagon                                      ...
# 89264ad92d3ffff              1             4.0  ...           1  \
# 89264ad92dbffff              1             4.0  ...           1
# 89264ad9403ffff              1             4.0  ...           1
# 89264ad940bffff              1             4.0  ...           1
# 89264ad940fffff              1             4.0  ...           1
#
#                  sum_years_diff  sum_property_loss  total_loss  total_years
# h3_hexagon
# 89264ad92d3ffff             0.0               0.03        0.03            1  \
# 89264ad92dbffff             0.0               0.03        0.03            1
# 89264ad9403ffff             0.0               0.03        0.03            1
# 89264ad940bffff             0.0               0.03        0.03            1
# 89264ad940fffff             0.0               0.03        0.03            1
#
#                  avg_loss_per_year avg_frequency avg_property_loss
# h3_hexagon
# 89264ad92d3ffff               0.03           inf              0.03  \
# 89264ad92dbffff               0.03           inf              0.03
# 89264ad9403ffff               0.03           inf              0.03
# 89264ad940bffff               0.03           inf              0.03
# 89264ad940fffff               0.03           inf              0.03
#
#                 avg_mag_freq names
# h3_hexagon
# 89264ad92d3ffff          inf   NaN
# 89264ad92dbffff          inf   NaN
# 89264ad9403ffff          inf   NaN
# 89264ad940bffff          inf   NaN
# 89264ad940fffff          inf   NaN
#
# [5 rows x 38 columns]

# %%
def convert_to_string(dates_list):
    return [date.strftime('%Y-%m-%d') for date in dates_list]

final['date'] = final['date'].apply(convert_to_string)

# %%
final.columns
# Out:
# Index(['geometry', 'tornado_count', 'mag_h3_history', 'inj_h3_history',
#        'fat_h3_history', 'loss_h3_history', 'closs_h3_history',
#        'len_h3_history', 'wid_h3_history', 'yr', 'mo', 'date', 'mag_stats',
#        'loss_stats', 'closs_stats', 'inj_stats', 'fat_stats', 'len_stats',
#        'wid_stats', 'days_diff', 'years_diff', 'num_events', 'sum_years_diff',
#        'sum_property_loss', 'total_loss', 'total_years', 'avg_loss_per_year',
#        'avg_frequency', 'avg_property_loss', 'avg_mag_freq',
#        'years_since_event'],
#       dtype='object')

# %%
#final_stats = final.drop([0, 1, 'geometry'], axis=1)
#final_geom = final.drop([0], axis=1)

##############################

print("Successfully dissolved...")
final.to_csv(directory / f"h3_hexagons_tornado/{lookup}_final_geom.csv")
print("Wrote to csv...")
# Out:
# Successfully dissolved...
# Wrote to csv...
